# %%
# !pip install sympy==1.6
# Out:
# Collecting sympy==1.6
#   Downloading https://files.pythonhosted.org/packages/a4/ea/590e1f2c73a1b8f878a1398b0edbf261d660439a9f851accb39db73d8e2f/sympy-1.6-py3-none-any.whl (5.8MB)
#      |████████████████████████████████| 5.8MB 3.7MB/s
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.6/dist-packages (from sympy==1.6) (1.1.0)
# Installing collected packages: sympy
#   Found existing installation: sympy 1.1.1
#     Uninstalling sympy-1.1.1:
#       Successfully uninstalled sympy-1.1.1
# Successfully installed sympy-1.6

# %%
from sympy import *
x, y, z, t = symbols('x y z t', real=True)
a, b, c  = symbols('a b c', real=True)
#from sympy.parsing.latex import parse_latex
import matplotlib.pyplot as plt

from sympy.plotting.plot import List2DSeries

# %matplotlib inline

# %%
plot_implicit(List2DSeries([1,2,3],[2,-1,4]))
# Out:
# ---------------------------------------------------------------------------
# SympifyError                              Traceback (most recent call last)
# <ipython-input-2-2aae79b5b7b0> in <module>()
# ----> 1 plot_implicit(List2DSeries([1,2,3],[2,-1,4]))
#
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot_implicit.py in plot_implicit(expr, x_var, y_var, adaptive, depth, points, line_color, show, **kwargs)
#     370
#     371     elif not isinstance(expr, Relational):
# --> 372         expr = Eq(expr, 0)
#     373         has_equality = True
#     374     elif isinstance(expr, (Equality, GreaterThan, LessThan)):
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/relational.py in __new__(cls, lhs, rhs, **options)
#     492             rhs = 0
#     493
# --> 494         lhs = _sympify(lhs)
#     495         rhs = _sympify(rhs)
#     496
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/sympify.py in _sympify(a)
#     437
#     438     """
# --> 439     return sympify(a, strict=True)
#     440
#     441
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     358
#     359     if strict:
# --> 360         raise SympifyError(a)
#     361
#     362     if iterable(a):
#
# SympifyError: SympifyError: <sympy.plotting.plot.List2DSeries object at 0x7f599acd02b0>

# %%
p1 = plot_implicit(Eq(y,x**2),show=False)
p1.extend(plot_implicit(Eq(x,-1), show=False))
#p1.append(List2DSeries([1,2],[2,-1]))
x=-1
y=1
p1.append(List2DSeries([x-0.1,x+0.1],[y,y]))
#p1.extend(plt.plot([0],[0],'*'))
#fig = p1._backend.fig

p1.show()

# %%
plot_parametric()

# %%
p1 = plot_implicit(Eq(y,x**2), (x, -10, 10), (y, -10, 10))
fg =  p1._backend.fig
ax =  p1._backend.ax
ax

# %%
plt.scatter(-1,2, color='r')

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
from sympy import *

x, y = symbols("x y")
hp = plot_implicit(Eq(x**2 + y**2, 4), (x, -3, 3), (y, -3, 3))
fig = hp._backend.fig
ax = hp._backend.ax
xx = yy = np.linspace(-3,3)
ax.plot(xx,yy) # y = x
#ax.plot([0],[0],'o') # Point (0,0)
ax.set_aspect('equal','datalim')
fig.canvas.draw()
# Out:
# <div id='ce3897c2-9a96-43e2-8831-23be11753d50'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-7e6fd8ac1117> in <module>()
#       9 ax = hp._backend.ax
#      10 xx = yy = np.linspace(-3,3)
# ---> 11 ax.plot(xx,yy) # y = x
#      12 #ax.plot([0],[0],'o') # Point (0,0)
#      13 ax.set_aspect('equal','datalim')
#
# AttributeError: 'list' object has no attribute 'plot'
# <div id='997c710a-e45e-4f8c-967e-81e274f866d6'></div>

# %%
import numpy as np

x, y = symbols("x y")
hp = plot_implicit(Eq(x**2 + y**2, 4), (x, -3, 3), (y, -3, 3))
fig = hp._backend.fig
ax = hp._backend.ax
xx = yy = np.linspace(-3,3)
ax.plot(xx,yy) # y = x
ax.plot([-1],[1],'o') # Point (0,0)
ax.set_aspect('equal','datalim')
fig.canvas.draw()
# Out:
# <div id='bf15db5b-d9b4-44b9-add8-ccbee35c92e2'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-6e2c0acd80f2> in <module>()
#       6 ax = hp._backend.ax
#       7 xx = yy = np.linspace(-3,3)
# ----> 8 ax.plot(xx,yy) # y = x
#       9 ax.plot([-1],[1],'o') # Point (0,0)
#      10 ax.set_aspect('equal','datalim')
#
# AttributeError: 'list' object has no attribute 'plot'
# <div id='85b2dc2f-cbbc-47f9-9bc9-590e2ecfe20e'></div>

# %%
import matplotlib.pyplot as plt
import numpy as np


fig, ax = plt.subplots(1,1)
xx,yy = np.linspace(-3,3), np.linspace(-3,3)
x,y = np.meshgrid(xx,yy)
ax.contour(x, y, (x**2+y**2-4), [0]);
ax.plot([0],[0],"o")
ax.plot(xx,yy)
ax.set_aspect('equal','datalim')
# Out:
# <div id='e3820b4e-2744-4235-a5bf-f81f39585c5d'></div>
# <div id='d8e5b225-594e-4e12-9dec-52d7cc16ee22'></div>

# %%
a=1
parse_latex('ax^2-4').subs('a',a)
# Out:
#  2
# x  - 4

# %%
S((x+1)*(x-1), evaluate=False)
# Out:
# (x - 1)⋅(x + 1)

# %%
(x+1)*(x-1)
# Out:
# (x - 1)⋅(x + 1)

# %%
S(2+3,evaluate=False)
# Out:
# 5
